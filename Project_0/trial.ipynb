# %%
from utils import get_stock_data_cached, plot_stock

df = get_stock_data_cached('sz.000001', '2024-04-01', '2025-04-01')
plot_stock(df, title='平安银行')
# Out:
# Loading from cache: data\sz.000001_2024-04-01_2025-04-01_d_2.csv
